# %%
import math
import numpy as np
import ceo
import matplotlib.pyplot as plt
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
# %matplotlib inline

# %%
#modes = ceo.Modes('M1modes',7,27)
modes = ceo.Modes('KarhunenLoeveModes',7,27)

# %%
print modes.N_MODE_AVAILABLE, modes.N_SAMPLE, modes.radius, modes.N_SET, modes.N_MODE
print modes.s2b.host()
# Out:
# 1001 256 4.25 1 27
# [0 0 0 0 0 0 0]

# %%
modes.a.shape, modes.M.shape, modes.S.shape
# Out:
# ((7, 27), (65536, 1001), (65536, 7))

# %%
M = modes.M.host()

# %%
plt.figure()
plt.imshow(np.reshape(M[:,1],(modes.N_SAMPLE,modes.N_SAMPLE)))
plt.colorbar()

# %%
plt.figure()
plt.imshow(np.reshape(M[:,162+4],(modes.N_SAMPLE,modes.N_SAMPLE)))
plt.colorbar()

# %%
modes.a[0,0] = 1e-6
modes.a[1,2] = 1e-6
modes.update()

# %%
S = modes.S.host()

# %%
plt.figure()
plt.imshow(np.reshape(S[:,0],(modes.N_SAMPLE,modes.N_SAMPLE)))
plt.colorbar()
plt.figure()
plt.imshow(np.reshape(S[:,1],(modes.N_SAMPLE,modes.N_SAMPLE)))
plt.colorbar()
