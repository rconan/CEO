# %%
import numpy as np
import math
from ceo import ceo
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
src = ceo.Source("R")

# %%
rays = ceo.Bundle(src,0.2,3,4,[0.0,0.0,-1])

# %%
rays_origin = rays.coordinates.host()
def rays_display(rays):
    return None
    print "RAYS:\n . coordinates:\n" , np.array_str(rays.coordinates.host().T,precision=3,suppress_small=True) , \
    "\n . directions:\n",  np.array_str(rays.directions.host().T,precision=3,suppress_small=True) , \
    "\n . OPL:\n",  np.array_str(rays.optical_path_length.host().T,precision=3,suppress_small=True)
rays_display(rays)

# %%
surf = ceo.Conic(-0.5,0.0,origin=[0.0,0.0,0.0],euler_angles=[0.0,-0*math.pi/20,0*math.pi/3])

# %%
print surf.R.T
np.dot(surf.R,surf.R.T)
# Out:
# [[ 1.  0.  0.]
#  [-0.  1.  0.]
#  [ 0. -0.  1.]]
# array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]], dtype=float32)

# %%
ceo.Transform_to_S(rays,surf)
rays_display(rays)

# %%
#ceo.Transform_to_R(rays,surf)
#rays_display(rays)

# %%
ceo.Intersect(rays,surf)
rays_display(rays)

# %%
ceo.Reflect(rays)
rays_display(rays)

# %%
ceo.Transform_to_R(rays,surf)
rays_display(rays)

# %%
def parametric_equation(rays,s):
    x = rays.coordinates.host()[:,0] + s*rays.directions.host()[:,0]    
    y = rays.coordinates.host()[:,1] + s*rays.directions.host()[:,1]    
    z = rays.coordinates.host()[:,2] + s*rays.directions.host()[:,2]
    return x,y,z

# %%
x,y,z = parametric_equation(rays,1.2)
#print x

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(25,25))
ax1 = fig.add_subplot(221, projection='3d')
ax2 = fig.add_subplot(222, projection='3d')
ax3 = fig.add_subplot(223, projection='3d')
ax4 = fig.add_subplot(224, projection='3d')
axs = [ax1,ax2,ax3,ax4]
rays_current = rays.coordinates.host();
for k in range(rays_origin.shape[0]):
    xp = [rays_origin[k,0],rays_current[k,0],x[k]]
    yp = [rays_origin[k,1],rays_current[k,1],y[k]]
    zp = [rays_origin[k,2],rays_current[k,2],z[k]]
    for ax in axs:
         ax.plot3D(xp,yp,zp)
         ax.set_xlabel('X') 
         ax.set_ylabel('Y')
         ax.set_zlabel('Z')
ax1.view_init(elev=0,azim=90)
ax2.view_init(elev=0,azim=0)
ax3.view_init(elev=90,azim=90)

# %%
d = rays.directions.host()
d.shape
# Out:
# (12, 3)

# %%
d[:,1]
# Out:
# array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,  -9.97506231e-02,  -1.98019803e-01,
#          0.00000000e+00,  -1.22159282e-17,  -2.42504309e-17,
#          0.00000000e+00,   9.97506231e-02,   1.98019803e-01], dtype=float32)

# %%
rays.optical_path_length.host()
# Out:
# array([[ 1.        ],
#        [ 0.9975    ],
#        [ 0.99000001],
#        [ 1.        ],
#        [ 0.9975    ],
#        [ 0.99000001],
#        [ 1.        ],
#        [ 0.9975    ],
#        [ 0.99000001],
#        [ 1.        ],
#        [ 0.9975    ],
#        [ 0.99000001]], dtype=float32)
