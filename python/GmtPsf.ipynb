# %% [markdown]
# # Giant Magellan Telescope Images

# %%
import numpy as np
from ceo import ceo
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Diffraction limited image

# %% [markdown]
# The point source:

# %%
n = 512
src = ceo.Source("K",resolution=(n,n),magnitude=14)

# %% [markdown]
# The telescope:

# %%
tel = ceo.GMT(n,25.5)
src.masked(tel)

# %% [markdown]
# The imager sampling the GMT image at 4 times the Shannon criteria:

# %%
osf = 8
imgr = ceo.Imaging(1,n,DFT_osf=osf,N_PX_IMAGE=128)

# %%
imgr.propagate(src)

# %%
figure(1)
ax = imshow(imgr.frame.host()**0.5,interpolation='None') 
colorbar(ax)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7fa740ef5c68>

# %% [markdown]
# ## Turbulence images

# %%
gs = ceo.Source("K",resolution=(n,n),magnitude=14)
gs.masked(tel)
atm = ceo.Atmosphere(15e-2,30,wind_speed=10)

# %%
imgr1 = ceo.Imaging(1,n,N_PX_IMAGE=128)

# %%
p = 25.5/n
print p*1e2
# Out:
# 4.98046875

# %% [markdown]
# ### Snapshot image at T=1s

# %%
imgr1.reset()
atm.get_phase_screen(gs,p,n,p,n,1)
imgr1.propagate(gs)
ax = imshow(imgr1.frame.host(),interpolation='None') 
colorbar(ax)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7fa740d23b90>

# %% [markdown]
# ### Snapshot image at T=2s

# %%
imgr1.reset()
atm.get_phase_screen(gs,p,n,p,n,2)
imgr1.propagate(gs)
ax = imshow(imgr1.frame.host(),interpolation='None') 
colorbar(ax)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f5c6c7d5ea8>

# %% [markdown]
# ### Snapshot image at T=10s

# %%
imgr1.reset()
atm.get_phase_screen(gs,p,n,p,n,10)
imgr1.propagate(gs)
ax = imshow(imgr1.frame.host(),interpolation='None') 
colorbar(ax)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f5c6c6299e0>

# %% [markdown]
# ### 20s exposure image sampled every 0.1s

# %%
imgr1.reset()
tau = 1e-1
T = 0.0
tid = ceo.StopWatch()
tid.tic()
while T<=20:
    T += tau
    atm.get_phase_screen(gs,p,n,p,n,T)
    imgr1.propagate(gs)
tid.toc()
ax = imshow(imgr1.frame.host(),interpolation='None') 
colorbar(ax)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7fa740c032d8>
